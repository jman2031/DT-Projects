# %% [markdown]
# ## Eval-3 Advertising Sales Channel Prediction

# %% [markdown]
# #### Problem Statement: Sales Channel Prediction Case Study
#
# - When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# - The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.
#
# - The below link provided is for downloading the dataset.
#
# Download Files: https://github.com/dsrscientist/DSData/blob/master/Advertising.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Advertising.csv")
pd.set_option('display.max_rows', None)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# 20           21  218.4   27.7       53.4   18.0
# 21           22  237.4    5.1       23.5   12.5
# 22           23   13.2   15.9       49.6    5.6
# 23           24  228.3   16.9       26.2   15.5
# 24           25   62.3   12.6       18.3    9.7
# 25           26  262.9    3.5       19.5   12.0
# 26           27  142.9   29.3       12.6   15.0
# 27           28  240.1   16.7       22.9   15.9
# 28           29  248.8   27.1       22.9   18.9
# 29           30   70.6   16.0       40.8   10.5
# 30           31  292.9   28.3       43.2   21.4
# 31           32  112.9   17.4       38.6   11.9
# 32           33   97.2    1.5       30.0    9.6
# 33           34  265.6   20.0        0.3   17.4
# 34           35   95.7    1.4        7.4    9.5
# 35           36  290.7    4.1        8.5   12.8
# 36           37  266.9   43.8        5.0   25.4
# 37           38   74.7   49.4       45.7   14.7
# 38           39   43.1   26.7       35.1   10.1
# 39           40  228.0   37.7       32.0   21.5
# 40           41  202.5   22.3       31.6   16.6
# 41           42  177.0   33.4       38.7   17.1
# 42           43  293.6   27.7        1.8   20.7
# 43           44  206.9    8.4       26.4   12.9
# 44           45   25.1   25.7       43.3    8.5
# 45           46  175.1   22.5       31.5   14.9
# 46           47   89.7    9.9       35.7   10.6
# 47           48  239.9   41.5       18.5   23.2
# 48           49  227.2   15.8       49.9   14.8
# 49           50   66.9   11.7       36.8    9.7
# 50           51  199.8    3.1       34.6   11.4
# 51           52  100.4    9.6        3.6   10.7
# 52           53  216.4   41.7       39.6   22.6
# 53           54  182.6   46.2       58.7   21.2
# 54           55  262.7   28.8       15.9   20.2
# 55           56  198.9   49.4       60.0   23.7
# 56           57    7.3   28.1       41.4    5.5
# 57           58  136.2   19.2       16.6   13.2
# 58           59  210.8   49.6       37.7   23.8
# 130         131    0.7   39.6        8.7    1.6
# 131         132  265.2    2.9       43.0   12.7
# 132         133    8.4   27.2        2.1    5.7
# 133         134  219.8   33.5       45.1   19.6
# 134         135   36.9   38.6       65.6   10.8
# 135         136   48.3   47.0        8.5   11.6
# 136         137   25.6   39.0        9.3    9.5
# 137         138  273.7   28.9       59.7   20.8
# 138         139   43.0   25.9       20.5    9.6
# 139         140  184.9   43.9        1.7   20.7
# 140         141   73.4   17.0       12.9   10.9
# 141         142  193.7   35.4       75.6   19.2
# 142         143  220.5   33.2       37.9   20.1
# 143         144  104.6    5.7       34.4   10.4
# 144         145   96.2   14.8       38.9   11.4
# 145         146  140.3    1.9        9.0   10.3
# 146         147  240.1    7.3        8.7   13.2
# 147         148  243.2   49.0       44.3   25.4
# 148         149   38.0   40.3       11.9   10.9
# 149         150   44.7   25.8       20.6   10.1
# 150         151  280.7   13.9       37.0   16.1
# 151         152  121.0    8.4       48.7   11.6
# 152         153  197.6   23.3       14.2   16.6
# 153         154  171.3   39.7       37.7   19.0
# 154         155  187.8   21.1        9.5   15.6
# 155         156    4.1   11.6        5.7    3.2
# 156         157   93.9   43.5       50.5   15.3
# 157         158  149.8    1.3       24.3   10.1
# 158         159   11.7   36.9       45.2    7.3
# 159         160  131.7   18.4       34.6   12.9
# 160         161  172.5   18.1       30.7   14.4
# 161         162   85.7   35.8       49.3   13.3
# 162         163  188.4   18.1       25.6   14.9
# 163         164  163.5   36.8        7.4   18.0
# 164         165  117.2   14.7        5.4   11.9
# 165         166  234.5    3.4       84.8   11.9
# 166         167   17.9   37.6       21.6    8.0
# 167         168  206.8    5.2       19.4   12.2
# 168         169  215.4   23.6       57.6   17.1
# 169         170  284.3   10.6        6.4   15.0
# 170         171   50.0   11.6       18.4    8.4
# 171         172  164.5   20.9       47.4   14.5
# 172         173   19.6   20.1       17.0    7.6
# 173         174  168.4    7.1       12.8   11.7
# 174         175  222.4    3.4       13.1   11.5
# 175         176  276.9   48.9       41.8   27.0
# 176         177  248.4   30.2       20.3   20.2
# 177         178  170.2    7.8       35.2   11.7
# 178         179  276.7    2.3       23.7   11.8
# 179         180  165.6   10.0       17.6   12.6
# 180         181  156.6    2.6        8.3   10.5
# 181         182  218.5    5.4       27.4   12.2
# 182         183   56.2    5.7       29.7    8.7
# 183         184  287.6   43.0       71.8   26.2
# 184         185  253.8   21.3       30.0   17.6
# 185         186  205.0   45.1       19.6   22.6
# 186         187  139.5    2.1       26.6   10.3
# 187         188  191.1   28.7       18.2   17.3
# 188         189  286.0   13.9        3.7   15.9
# 189         190   18.7   12.1       23.4    6.7
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# #### Checking Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#if has null value, fill those by imputation
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Data shows no null values as seen from the heatmap, so let's proceed ahead.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #gives nos of rows and columns
# Out:
# (200, 5)

# %%
df.columns #name of columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
#As the "Unnamed: 0' column has no valuable information other than serial numbers, we can drop this column.
df = df.drop("Unnamed: 0",axis=1)
df.head(2)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4

# %% [markdown]
# ## Visualization of the data

# %%
#Checking all columns:

for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
a=sns.swarmplot(x='sales',y='TV',data=df)
plt.title('Sales of TV')
plt.show()

# %% [markdown]
# The above graph shows that there is a direct positive relation between the 'sales' and the 'TV' column.

# %%
sns.catplot(x='sales',y='radio', data = df)

# %% [markdown]
# Same pattern as above wrt sales is followed in this graph too, where there is a direct positive relationship between the "sales" and 'radio' column.

# %%
sns.scatterplot(x="sales",y="TV",data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='TV'>

# %%
sns.regplot(x="sales",y="newspaper",data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %% [markdown]
# Here ther elationship between the columns "sales" and "newspaper" is a bit scattered, which shows that the sales from newspaper isnt much compared to radio and tv

# %%
sns.lmplot(x="sales",y="radio",data=df)

# %% [markdown]
# We can see a linear line here in the graph, showing linear relationship bewteen 'sales' and the 'radio' column

# %%
plt.title("Newspaper sales")
sns.violinplot(x='newspaper',data=df)
# Out:
# <AxesSubplot:title={'center':'Newspaper sales'}, xlabel='newspaper'>

# %% [markdown]
# This shows the density of the sales from the newspaper, which is max in the range of 16-20.

# %%
sns.pairplot(data=df)

# %% [markdown]
# ## EXPLATORY DATA ANALYSIS(EDA)

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#plotting heat map for better understanding:
plt.figure(figsize=(10,5))
sns.heatmap(df.describe(), annot=True,fmt='0.4f')
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.title("sales variables")
plt.show()

# %% [markdown]
# In the above heatmap:
# - The mean in all the columns is > median, except in the 'TV' column, which means that the distribution is positively skewed.
# - The standard deviation is very high in the "TV" column which means that the data is highly spread. It is spread less though in the "newspaper" and "radio" column.
# - The difference between the 75% percentile and max is more in the newspaper column, which indicates that outliers may be present.

# %% [markdown]
# ## Check Correlation of columns with the target:

# %%
df.corr() #correlation
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df.corr(),cmap='RdBu',annot=True,linewidth=0.5,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - There is no negative correlation too with the target column ('sales').
# - The highest correlation can be seen with the "TV" column while the lowest can be seen with the 'newspaper' column

# %%
df.corr()['sales'].sort_values(ascending=False)
# Out:
# sales        1.000000
# TV           0.782224
# radio        0.576223
# newspaper    0.228299
# Name: sales, dtype: float64

# %%
#checking the columns which are positively and negatively corelated with the target column:

plt.figure(figsize=(6,3))
df.corr()["sales"].sort_values(ascending=False).plot(kind='bar', color='maroon')
plt.xlabel('Variables',fontsize=14)
plt.ylabel("sales",fontsize=14)
plt.title("correlation",fontsize=15)
plt.show()

# %% [markdown]
# ## Check Skewness
# Threshold=+/-0.5

# %%
x=df.drop('sales',axis=1)
y=df['sales']

# %%
df.skew().sort_values(ascending=False)
# Out:
# newspaper    0.894720
# sales        0.407571
# radio        0.094175
# TV          -0.069853
# dtype: float64

# %% [markdown]
# Skewness is seen in the "newspaper" data.

# %%
#Removing Skewness with square root method
df['newspaper']=np.sqrt(df['newspaper'])
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.062388
# sales        0.407571
# dtype: float64

# %%
df['newspaper'].plot(kind='kde',subplots=True,layout=(2,6),figsize=(15,6))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %% [markdown]
# #### Skewness is removed, as seen from the above graph

# %% [markdown]
# ## Checking Outliers:

# %%
df.plot(kind='box',subplots=True,layout=(1,4),figsize=(12,7))
# Out:
# TV              AxesSubplot(0.125,0.125;0.168478x0.755)
# radio        AxesSubplot(0.327174,0.125;0.168478x0.755)
# newspaper    AxesSubplot(0.529348,0.125;0.168478x0.755)
# sales        AxesSubplot(0.731522,0.125;0.168478x0.755)
# dtype: object

# %%
plt.boxplot(df['newspaper'])
plt.show()

# %% [markdown]
# No visible outliers can be seen in these plots, but to counter check, we can check with zscore method

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.head()
# Out:
#          TV     radio  newspaper     sales
# 0  0.969852  0.981522   1.563095  1.552053
# 1  1.197376  1.082808   0.774855  0.696046
# 2  1.516155  1.528463   1.566049  0.907406
# 3  0.052050  1.217855   1.233576  0.860330
# 4  0.394182  0.841614   1.230360  0.215683

# %%
#threshold for zscore values-----> above 3 are considered as outliers.

threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# No outliers detected.

# %% [markdown]
# ## Scaling The Data of the independent columns using Standard Scaler
# ##### Since the data is continous we use the linear regression method.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
ln=LinearRegression()
X=sc.fit_transform(x)
x=X
x
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01],
#        [ 7.90028350e-01,  4.96973404e-02, -1.22232878e+00],
#        [-1.43908760e+00,  7.99208859e-01,  1.62704048e+00],
#        [-5.78501712e-01, -1.05768905e+00, -1.07502697e+00],
#        [-6.17035408e-01, -1.24000266e+00, -1.03359834e+00],
#        [ 3.49810063e-01, -9.42898996e-01, -1.11185242e+00],
#        [ 1.59456522e+00,  1.26512143e+00,  1.64085003e+00],
#        [ 9.93206022e-01, -9.90165488e-01, -1.00597925e+00]])

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
# 30     21.4
# 31     11.9
# 32      9.6
# 33     17.4
# 34      9.5
# 35     12.8
# 36     25.4
# 37     14.7
# 38     10.1
# 39     21.5
# 40     16.6
# 41     17.1
# 42     20.7
# 43     12.9
# 44      8.5
# 45     14.9
# 46     10.6
# 47     23.2
# 48     14.8
# 49      9.7
# 50     11.4
# 51     10.7
# 52     22.6
# 53     21.2
# 54     20.2
# 55     23.7
# 56      5.5
# 57     13.2
# 58     23.8
# 59     18.4
# 60      8.1
# 61     24.2
# 62     15.7
# 63     14.0
# 64     18.0
# 65      9.3
# 66      9.5
# 67     13.4
# 68     18.9
# 69     22.3
# 70     18.3
# 71     12.4
# 72      8.8
# 73     11.0
# 74     17.0
# 75      8.7
# 76      6.9
# 77     14.2
# 78      5.3
# 79     11.0
# 80     11.8
# 81     12.3
# 82     11.3
# 83     13.6
# 84     21.7
# 85     15.2
# 86     12.0
# 87     16.0
# 88     12.9
# 89     16.7
# 90     11.2
# 91      7.3
# 92     19.4
# 93     22.2
# 94     11.5
# 95     16.9
# 96     11.7
# 97     15.5
# 98     25.4
# 99     17.2
# 100    11.7
# 101    23.8
# 102    14.8
# 103    14.7
# 104    20.7
# 105    19.2
# 106     7.2
# 107     8.7
# 108     5.3
# 109    19.8
# 110    13.4
# 111    21.8
# 112    14.1
# 113    15.9
# 114    14.6
# 115    12.6
# 116    12.2
# 117     9.4
# 118    15.9
# 119     6.6
# 120    15.5
# 121     7.0
# 122    11.6
# 123    15.2
# 124    19.7
# 125    10.6
# 126     6.6
# 127     8.8
# 128    24.7
# 129     9.7
# 130     1.6
# 131    12.7
# 132     5.7
# 133    19.6
# 134    10.8
# 135    11.6
# 136     9.5
# 137    20.8
# 138     9.6
# 139    20.7
# 140    10.9
# 141    19.2
# 142    20.1
# 143    10.4
# 144    11.4
# 145    10.3
# 146    13.2
# 147    25.4
# 148    10.9
# 149    10.1
# 150    16.1
# 151    11.6
# 152    16.6
# 153    19.0
# 154    15.6
# 155     3.2
# 156    15.3
# 157    10.1
# 158     7.3
# 159    12.9
# 160    14.4
# 161    13.3
# 162    14.9
# 163    18.0
# 164    11.9
# 165    11.9
# 166     8.0
# 167    12.2
# 168    17.1
# 169    15.0
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, dtype: float64

# %% [markdown]
# # Training of the data

# %% [markdown]
# ### Finding the best random fit

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=i)
    ln.fit(x_train, y_train)
    pred_train = ln.predict(x_train)
    pred_test = ln.predict(x_test)
    print(f"At random state {i}, the training accuracy is : {r2_score(y_train,pred_train)*100}")
    print(f"At random state {i}, the testing accuracy is :  {r2_score(y_test,pred_test)*100}")
    print("\n")
# Out:
# At random state 1, the training accuracy is : 89.59372632325174
# At random state 1, the testing accuracy is :  89.27605914615386
#
#
# At random state 2, the training accuracy is : 91.51707412454462
# At random state 2, the testing accuracy is :  75.75894500772722
#
#
# At random state 3, the training accuracy is : 89.30288385772916
# At random state 3, the testing accuracy is :  91.38375011080568
#
#
# At random state 4, the training accuracy is : 89.11672911176578
# At random state 4, the testing accuracy is :  90.85774752313168
#
#
# At random state 5, the training accuracy is : 89.56962280033927
# At random state 5, the testing accuracy is :  89.84204533332628
#
#
# At random state 6, the training accuracy is : 89.15418760966583
# At random state 6, the testing accuracy is :  92.2433347392203
#
#
# At random state 7, the training accuracy is : 89.29164670647455
# At random state 7, the testing accuracy is :  90.95550600904052
#
#
# At random state 8, the training accuracy is : 90.88025724048053
# At random state 8, the testing accuracy is :  84.60595754263389
#
#
# At random state 9, the training accuracy is : 88.97851719766416
# At random state 9, the testing accuracy is :  92.56258465335007
#
#
# At random state 10, the training accuracy is : 92.09087553499528
# At random state 10, the testing accuracy is :  83.53672324670593
#
#
# At random state 11, the training accuracy is : 91.11583949248848
# At random state 11, the testing accuracy is :  84.49174816183897
#
#
# At random state 12, the training accuracy is : 89.1451009902517
# At random state 12, the testing accuracy is :  91.25583321991083
#
#
# At random state 13, the training accuracy is : 88.69244310370577
# At random state 13, the testing accuracy is :  93.08589334107374
#
#
# At random state 14, the training accuracy is : 90.8635420499295
# At random state 14, the testing accuracy is :  85.49663199763197
#
#
# At random state 15, the training accuracy is : 89.35846767022744
# At random state 15, the testing accuracy is :  90.64939179490466
#
#
# At random state 16, the training accuracy is : 89.2634156753275
# At random state 16, the testing accuracy is :  91.86425380311198
#
#
# At random state 17, the training accuracy is : 91.16438501096809
# At random state 17, the testing accuracy is :  82.66375240641091
#
#
# At random state 18, the training accuracy is : 90.58350355666276
# At random state 18, the testing accuracy is :  86.91428348137913
#
#
# At random state 19, the training accuracy is : 89.36653113157833
# At random state 19, the testing accuracy is :  90.34108801676061
#
#
# At random state 20, the training accuracy is : 89.39415029759354
# At random state 20, the testing accuracy is :  90.32049399335233
#
#
# At random state 21, the training accuracy is : 88.76272528162707
# At random state 21, the testing accuracy is :  92.20737408493859
#
#
# At random state 22, the training accuracy is : 88.9996507588738
# At random state 22, the testing accuracy is :  91.82667532378174
#
#
# At random state 23, the training accuracy is : 89.21659364123988
# At random state 23, the testing accuracy is :  91.0204221189731
#
#
# At random state 24, the training accuracy is : 89.46529864968562
# At random state 24, the testing accuracy is :  90.43170168345029
#
#
# At random state 25, the training accuracy is : 90.07883778149751
# At random state 25, the testing accuracy is :  87.38569641880865
#
#
# At random state 26, the training accuracy is : 89.98325917728893
# At random state 26, the testing accuracy is :  87.56915597547017
#
#
# At random state 27, the training accuracy is : 89.47281937728894
# At random state 27, the testing accuracy is :  90.64360707520687
#
#
# At random state 28, the training accuracy is : 89.96821021764309
# At random state 28, the testing accuracy is :  88.41395816464689
#
#
# At random state 29, the training accuracy is : 88.96422572594605
# At random state 29, the testing accuracy is :  91.24795091328944
#
#
# At random state 30, the training accuracy is : 89.3363345130229
# At random state 30, the testing accuracy is :  90.80112550671721
#
#
# At random state 31, the training accuracy is : 88.59036462267696
# At random state 31, the testing accuracy is :  92.84346926567392
#
#
# At random state 32, the training accuracy is : 91.72972779129942
# At random state 32, the testing accuracy is :  77.68844650932812
#
#
# At random state 33, the training accuracy is : 89.62848476126537
# At random state 33, the testing accuracy is :  89.37288845297464
#
#
# At random state 34, the training accuracy is : 89.70495535067477
# At random state 34, the testing accuracy is :  89.25087896627704
#
#
# At random state 35, the training accuracy is : 91.49802728230205
# At random state 35, the testing accuracy is :  78.64906125568902
#
#
# At random state 36, the training accuracy is : 88.873873652443
# At random state 36, the testing accuracy is :  92.6530749168601
#
#
# At random state 37, the training accuracy is : 89.97277119781725
# At random state 37, the testing accuracy is :  88.37033479022513
#
#
# At random state 38, the training accuracy is : 89.7221377871517
# At random state 38, the testing accuracy is :  89.27131887797296
#
#
# At random state 39, the training accuracy is : 89.89586369412048
# At random state 39, the testing accuracy is :  87.89549979127554
#
#
# At random state 40, the training accuracy is : 92.0068668721091
# At random state 40, the testing accuracy is :  79.82652261831078
#
#
# At random state 41, the training accuracy is : 90.06901704189823
# At random state 41, the testing accuracy is :  88.19813651740449
#
#
# At random state 42, the training accuracy is : 89.57008271017818
# At random state 42, the testing accuracy is :  89.9438024100912
#
#
# At random state 43, the training accuracy is : 88.8477223981934
# At random state 43, the testing accuracy is :  92.86102071081018
#
#
# At random state 44, the training accuracy is : 90.65895163213827
# At random state 44, the testing accuracy is :  83.1029045839692
#
#
# At random state 45, the training accuracy is : 89.5947647524022
# At random state 45, the testing accuracy is :  89.55882331233614
#
#
# At random state 46, the training accuracy is : 90.35142166671977
# At random state 46, the testing accuracy is :  85.08891379360347
#
#
# At random state 47, the training accuracy is : 89.86105026216174
# At random state 47, the testing accuracy is :  88.61176124930537
#
#
# At random state 48, the training accuracy is : 89.05303930227862
# At random state 48, the testing accuracy is :  91.92264895105909
#
#
# At random state 49, the training accuracy is : 91.38424680320801
# At random state 49, the testing accuracy is :  82.36013350803586
#
#
# At random state 50, the training accuracy is : 90.13713199191987
# At random state 50, the testing accuracy is :  84.75513251426332
#
#
# At random state 51, the training accuracy is : 89.35562677321687
# At random state 51, the testing accuracy is :  90.79126096145103
#
#
# At random state 52, the training accuracy is : 90.18280272898133
# At random state 52, the testing accuracy is :  88.11159773607994
#
#
# At random state 53, the training accuracy is : 88.87382038237429
# At random state 53, the testing accuracy is :  92.55679198924356
#
#
# At random state 54, the training accuracy is : 89.19832932654931
# At random state 54, the testing accuracy is :  91.75053931302267
#
#
# At random state 55, the training accuracy is : 89.46672493883487
# At random state 55, the testing accuracy is :  90.17603460127577
#
#
# At random state 56, the training accuracy is : 89.89109930720286
# At random state 56, the testing accuracy is :  88.81081877827506
#
#
# At random state 57, the training accuracy is : 88.25580314985149
# At random state 57, the testing accuracy is :  94.07051178510068
#
#
# At random state 58, the training accuracy is : 91.27122894347019
# At random state 58, the testing accuracy is :  84.06715244241624
#
#
# At random state 59, the training accuracy is : 88.93082812955636
# At random state 59, the testing accuracy is :  92.51177591187607
#
#
# At random state 60, the training accuracy is : 89.24386252509565
# At random state 60, the testing accuracy is :  90.99045150327532
#
#
# At random state 61, the training accuracy is : 89.93442759744174
# At random state 61, the testing accuracy is :  88.01295028531632
#
#
# At random state 62, the training accuracy is : 91.19756650926772
# At random state 62, the testing accuracy is :  84.17719904234858
#
#
# At random state 63, the training accuracy is : 89.47112911514465
# At random state 63, the testing accuracy is :  90.39175428258767
#
#
# At random state 64, the training accuracy is : 89.77794992748885
# At random state 64, the testing accuracy is :  88.18211467861748
#
#
# At random state 65, the training accuracy is : 89.69574133232423
# At random state 65, the testing accuracy is :  89.41749859375305
#
#
# At random state 66, the training accuracy is : 89.85647494060171
# At random state 66, the testing accuracy is :  88.98022957140043
#
#
# At random state 67, the training accuracy is : 89.9436698387886
# At random state 67, the testing accuracy is :  88.20468786272049
#
#
# At random state 68, the training accuracy is : 90.01781108442837
# At random state 68, the testing accuracy is :  86.90321403093822
#
#
# At random state 69, the training accuracy is : 88.70175330531669
# At random state 69, the testing accuracy is :  92.39270341483132
#
#
# At random state 70, the training accuracy is : 88.62312435968529
# At random state 70, the testing accuracy is :  92.60798727325859
#
#
# At random state 71, the training accuracy is : 91.63886175032458
# At random state 71, the testing accuracy is :  82.46989403826484
#
#
# At random state 72, the training accuracy is : 89.37422087162025
# At random state 72, the testing accuracy is :  90.72541868212966
#
#
# At random state 73, the training accuracy is : 90.77573496620701
# At random state 73, the testing accuracy is :  84.12998907053816
#
#
# At random state 74, the training accuracy is : 89.79415340515895
# At random state 74, the testing accuracy is :  88.06020302645325
#
#
# At random state 75, the training accuracy is : 89.43141208860872
# At random state 75, the testing accuracy is :  90.77086876495713
#
#
# At random state 76, the training accuracy is : 90.92025789360757
# At random state 76, the testing accuracy is :  75.35174994730747
#
#
# At random state 77, the training accuracy is : 88.59758983122315
# At random state 77, the testing accuracy is :  93.7880163249318
#
#
# At random state 78, the training accuracy is : 89.57285947454089
# At random state 78, the testing accuracy is :  90.26908232907813
#
#
# At random state 79, the training accuracy is : 89.17194183285055
# At random state 79, the testing accuracy is :  90.4710622824869
#
#
# At random state 80, the training accuracy is : 91.61683973913905
# At random state 80, the testing accuracy is :  80.70473986760943
#
#
# At random state 81, the training accuracy is : 90.33802332142854
# At random state 81, the testing accuracy is :  86.20423894967139
#
#
# At random state 82, the training accuracy is : 91.54244887223794
# At random state 82, the testing accuracy is :  80.14727140935159
#
#
# At random state 83, the training accuracy is : 88.40310976077721
# At random state 83, the testing accuracy is :  93.73350368424964
#
#
# At random state 84, the training accuracy is : 89.51392078054552
# At random state 84, the testing accuracy is :  90.07597814614812
#
#
# At random state 85, the training accuracy is : 90.86027174680294
# At random state 85, the testing accuracy is :  84.39638394828847
#
#
# At random state 86, the training accuracy is : 89.41525565676501
# At random state 86, the testing accuracy is :  91.00622221201643
#
#
# At random state 87, the training accuracy is : 91.18983221676123
# At random state 87, the testing accuracy is :  76.26125810244505
#
#
# At random state 88, the training accuracy is : 90.95202869396249
# At random state 88, the testing accuracy is :  84.02068643199276
#
#
# At random state 89, the training accuracy is : 90.00068536682569
# At random state 89, the testing accuracy is :  87.63063367531691
#
#
# At random state 90, the training accuracy is : 90.31056838494878
# At random state 90, the testing accuracy is :  85.15399308497919
#
#
# At random state 91, the training accuracy is : 88.73766899072166
# At random state 91, the testing accuracy is :  90.42137225502287
#
#
# At random state 92, the training accuracy is : 87.91722270470883
# At random state 92, the testing accuracy is :  95.1970719510946
#
#
# At random state 93, the training accuracy is : 89.29605913041914
# At random state 93, the testing accuracy is :  91.17655020936756
#
#
# At random state 94, the training accuracy is : 90.84398174091196
# At random state 94, the testing accuracy is :  85.59316851679387
#
#
# At random state 95, the training accuracy is : 89.35659928494455
# At random state 95, the testing accuracy is :  89.51810793790584
#
#
# At random state 96, the training accuracy is : 90.35998291188064
# At random state 96, the testing accuracy is :  85.95641556662493
#
#
# At random state 97, the training accuracy is : 89.00751965631105
# At random state 97, the testing accuracy is :  91.18128867084084
#
#
# At random state 98, the training accuracy is : 88.19661469883454
# At random state 98, the testing accuracy is :  94.00331814664702
#
#
# At random state 99, the training accuracy is : 89.06288862925659
# At random state 99, the testing accuracy is :  92.00846680148507

# %% [markdown]
# ##### At random state 45, the testing accuracy is :  89.55882331233613 == 90%

# %% [markdown]
# Moving on with the train test split method, considering the above parameters.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=45)
x_train.shape,x_test.shape, y_train.shape,y_test.shape
# Out:
# ((160, 3), (40, 3), (160,), (40,))

# %% [markdown]
# ### Linear regression

# %%
ln.fit(x_train,y_train)
pred_test=ln.predict(x_test)
pred_train=ln.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 1.0788802763848644
# Mean squared error: 2.256494247280932
# Root mean squared error: 1.5021631892976648
# R2 Score= 89.55882331233614

# %% [markdown]
# ### Lasso regression

# %%
l=Lasso() 
l.fit(x_train,y_train)
pred_test=l.predict(x_test)
pred_train=l.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('lasso R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 1.4649127976246827
# Mean squared error: 3.7597374233562633
# Root mean squared error: 1.9390042350021475
# lasso R2 Score= 82.60306544818883

# %% [markdown]
# ### Ride regression

# %%
r=Ridge() 
r.fit(x_train,y_train)
pred_test=r.predict(x_test)
pred_train=r.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('ridge R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 1.0790458112507024
# Mean squared error: 2.242326276232233
# Root mean squared error: 1.4974399073860136
# ridge R2 Score= 89.62438088652603

# %% [markdown]
# ### Elastic Net

# %%
en=ElasticNet() 
en.fit(x_train,y_train)
pred_test=en.predict(x_test)
pred_train=en.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('en R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 1.8337294350175461
# Mean squared error: 5.309571699429431
# Root mean squared error: 2.304250789178433
# en R2 Score= 75.43172276358995

# %% [markdown]
# ### DecisionTreeRegression

# %%
dt=DecisionTreeRegressor() 
dt.fit(x_train,y_train)
pred_test=dt.predict(x_test)
pred_train=dt.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('dt R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.8825000000000003
# Mean squared error: 1.2532500000000006
# Root mean squared error: 1.1194864894227177
# dt R2 Score= 94.20100241798418

# %% [markdown]
# ### Random Forest Regression

# %%
rf=RandomForestRegressor() 
rf.fit(x_train,y_train)
pred_test=rf.predict(x_test)
pred_train=rf.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('rf R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.5723749999999981
# Mean squared error: 0.49595272499999654
# Root mean squared error: 0.704239110671934
# rf R2 Score= 97.70514370391452

# %% [markdown]
# ### Support vector Regression

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_test=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('svr R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.5180928332568763
# Mean squared error: 0.4730101365019378
# Root mean squared error: 0.6877573238446376
# svr R2 Score= 97.81130290217936

# %% [markdown]
# ### KNeighbors Regression

# %%
kn=KNeighborsRegressor()
kn.fit(x_train,y_train)
pred_test=kn.predict(x_test)
pred_train=kn.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('kn R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.6935000000000004
# Mean squared error: 0.8428100000000012
# Root mean squared error: 0.9180468397636371
# kn R2 Score= 96.10017701807399

# %% [markdown]
# ### GradientBoostingRegression

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred_test=gb.predict(x_test)
pred_train=gb.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('gb R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.5363932618152993
# Mean squared error: 0.5381423533697067
# Root mean squared error: 0.7335818654858548
# gb R2 Score= 97.50992522962598

# %% [markdown]
# ### AdaBoostRegression

# %%
ab=AdaBoostRegressor()
ab.fit(x_train,y_train)
pred_test=ab.predict(x_test)
pred_train=ab.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('ab R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.8202573588759066
# Mean squared error: 1.0549209696080575
# Root mean squared error: 1.0270934570953403
# ab R2 Score= 95.11870404789555

# %% [markdown]
# ### ExtraTreesRegression

# %%
et=ExtraTreesRegressor()
et.fit(x_train,y_train)
pred_test=et.predict(x_test)
pred_train=et.predict(x_train)
print('Error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error:',mean_squared_error(y_test,pred_test))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_test)))
print('et R2 Score=',r2_score(y_test,pred_test)*100)
# Out:
# Error:
# Mean absolute error: 0.3300999999999993
# Mean squared error: 0.17263264999999922
# Root mean squared error: 0.4154908542916429
# et R2 Score= 99.20119982451467

# %% [markdown]
# ##### ExtraTreesRegression gives the R2 Score of 99.20 == 99%

# %% [markdown]
# ## Cross Validation Method

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(ln,x,y,cv=5)
print("Cross validadtion score of Linear regression Model is", scr.mean())

scr=cross_val_score(l,x,y,cv=5)
print("Cross validadtion score of Lasso Regression is", scr.mean())

scr=cross_val_score(r,x,y,cv=5)
print("Cross validadtion score of Ridge Regression is", scr.mean())

scr=cross_val_score(en,x,y,cv=5)
print("Cross validadtion score of Elastic Net is", scr.mean())

scr=cross_val_score(dt,x,y,cv=5)
print("Cross validadtion score of Decision Tree is", scr.mean())

scr=cross_val_score(rf,x,y,cv=5)
print("Cross validadtion score of Random Forest is", scr.mean())

scr=cross_val_score(svr,x,y,cv=5)
print("Cross validadtion score of SVR is", scr.mean())

scr=cross_val_score(kn,x,y,cv=5)
print("Cross validadtion score of KNeighbors is", scr.mean())

scr=cross_val_score(gb,x,y,cv=5)
print("Cross validadtion score of Gradient Boosting is", scr.mean())

scr=cross_val_score(ab,x,y,cv=5)
print("Cross validadtion score of AdaBoost is", scr.mean())

scr=cross_val_score(et,x,y,cv=5)
print("Cross validadtion score of ExtraTrees is", scr.mean())
# Out:
# Cross validadtion score of Linear regression Model is 0.8871063495438435
# Cross validadtion score of Lasso Regression is 0.8175135660884789
# Cross validadtion score of Ridge Regression is 0.8871485586585471
# Cross validadtion score of Elastic Net is 0.7321683044431688
# Cross validadtion score of Decision Tree is 0.9558712181985853
# Cross validadtion score of Random Forest is 0.9761280018921713
# Cross validadtion score of SVR is 0.9016714405804581
# Cross validadtion score of KNeighbors is 0.940813583487013
# Cross validadtion score of Gradient Boosting is 0.9777628188216028
# Cross validadtion score of AdaBoost is 0.9532003537616909
# Cross validadtion score of ExtraTrees is 0.9876113413956222

# %% [markdown]
# #### Here, the best CV score for Extra Trees Regression is 98.76 == 99% which is equal to the R2 score of 99%.
# - Hence, we can say that, the Extra Trees Regression is the best algorithm for training this model

# %% [markdown]
# ### Finding the best fit line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_test, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual sales', fontsize=14)
plt.ylabel('Predicted sales', fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# The best fit line seems to cover all the points on the graph.

# %% [markdown]
# ## Hyper parameter tuning of best model above (Extra Tress Regessor)

# %%
from sklearn.model_selection import GridSearchCV

#creating parameters to pass in Grid serach
para={'n_estimators':[10,20,30],
      'max_depth':[4,5,6,7],
      'criterion':['squared_error', 'absolute_error'],
       'max_features':['sqrt', 'log2', 'None']}

# %%
GCV=GridSearchCV(ExtraTreesRegressor(),para,cv=5)
GCV.fit(x_train,y_train) #fiting the data in the model
GCV.best_params_         #printing the best parameter found by GCV
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 7,
#  'max_features': 'log2',
#  'n_estimators': 30}

# %%
ETR=ExtraTreesRegressor(criterion='squared_error', max_depth= 7, max_features= 'log2', n_estimators= 30) #finalized algorithm

# %%
fit=ETR.fit(x_train,y_train)

# %%
ETR_pred = ETR.predict(x_test) #predicting final model with best parameters

# %%
best_r2=(r2_score(y_test,ETR_pred)*100)              #checking final R2 Score
print("Best R2 Score for GCV best estimator", ETR, "is",best_r2)
# Out:
# Best R2 Score for GCV best estimator ExtraTreesRegressor(max_depth=7, max_features='log2', n_estimators=30) is 92.72411568238101

# %% [markdown]
# ## Saving the model

# %%
import joblib

joblib.dump(rf,'AdvertSales.obj')                                    #save the model as an object file
AdvertSales_from_joblib=joblib.load('AdvertSales.obj')                #load the model from the file

#use the loaded model to make predictions
new= AdvertSales_from_joblib.predict(x_test)

# %%
new
# Out:
# array([16.053,  8.451, 16.565, 23.11 , 12.137, 10.104, 19.452, 11.764,
#        18.223,  7.892, 10.442,  9.902, 12.762, 16.058, 15.453,  8.757,
#        14.812,  9.768, 22.034, 10.274, 19.742,  6.868, 12.276, 10.471,
#        18.322,  9.369, 19.66 , 12.733, 16.098, 15.165, 24.022, 21.837,
#        18.87 , 16.727, 11.724, 11.534, 16.519, 14.683, 13.949, 18.727])

# %% [markdown]
# ### Prediction:

# %%
original=np.array(y_test)
prediction=np.array(new)
dfnew = pd.DataFrame({"original":original,"prediction":new})
dfnew
# Out:
#     original  prediction
# 0       14.9      16.053
# 1        8.8       8.451
# 2       16.6      16.565
# 3       23.8      23.110
# 4       12.0      12.137
# 5        9.7      10.104
# 6       19.0      19.452
# 7       11.8      11.764
# 8       18.5      18.223
# 9        8.5       7.892
# 10      10.8      10.442
# 11      10.1       9.902
# 12      11.7      12.762
# 13      17.4      16.058
# 14      15.7      15.453
# 15       8.7       8.757
# 16      14.1      14.812
# 17       9.7       9.768
# 18      22.3      22.034
# 19      10.8      10.274
# 20      19.6      19.742
# 21       7.6       6.868
# 22      12.8      12.276
# 23      10.1      10.471
# 24      17.3      18.322
# 25       8.6       9.369
# 26      20.7      19.660
# 27      11.7      12.733
# 28      15.0      16.098
# 29      14.5      15.165
# 30      25.4      24.022
# 31      22.1      21.837
# 32      19.8      18.870
# 33      17.3      16.727
# 34      11.6      11.724
# 35      11.3      11.534
# 36      18.0      16.519
# 37      15.0      14.683
# 38      12.9      13.949
# 39      18.9      18.727

# %% [markdown]
# # END
