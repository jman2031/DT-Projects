# %% [markdown]
# ## Project 1 (Pract) :: World Happiness Report:
# https://github.com/dsrscientist/DSData/blob/master/happiness_score_dataset.csv
#
# Problem Statement:
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# What is Dystopia?
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# What are the residuals?
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.
#
# What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
#
# The Dystopia Residual is already provided in the dataset.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.
#
# You need to predict the happiness score considering all the other factors mentioned in the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import power_transform
from sklearn.metrics import r2_score
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df1

df=pd.DataFrame(data=df1)
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# #### Checking Info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
#if has null value, fill those by imputation
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull()) #checking null values with heat map
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### NO NULL VALUES, so let's proceed ahead.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# In this dataset,various factors are mentioned on which a country's or region's happiness is dependent, like 'Country', 'Region', 'Happiness Rank', 'Happiness Score','Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)','Generosity' and 'Dystopia Residual'.
# - It has 158 rows and 12 columns
# - Here the Happiness score can be the target, as the happiness of the country can be known from its happiness score.

# %% [markdown]
# # Visualization of the data

# %%
import seaborn as sns
sns.scatterplot(data=df,x='Happiness Score',y='Happiness Rank')
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Happiness Rank'>

# %%
sns.regplot(y='Happiness Score',x='Standard Error', data = df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.lmplot(y='Happiness Score',x='Economy (GDP per Capita)', data = df)

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y='Happiness Score',x='Economy (GDP per Capita)', hue='Region', data = df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.lmplot(y='Happiness Score',x='Family', data = df)

# %%
sns.lmplot(y='Happiness Score',x='Health (Life Expectancy)', data = df)

# %%
sns.lmplot(y='Happiness Score',x='Freedom', data = df)

# %%
sns.lmplot(y='Happiness Score',x='Trust (Government Corruption)', data = df)

# %%
sns.lmplot(y='Happiness Score',x='Generosity', data = df)

# %%
sns.lmplot(y='Happiness Score',x='Dystopia Residual', data = df)

# %% [markdown]
# # Encoding Data Frame
# Since the "Country" and "Region" are in string, we are converting those in numerical data with label encoder.

# %%
le=LabelEncoder() #le is the instance
#df['Country']=le.fit_transform(df['Country'])

list1=['Region','Country']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %% [markdown]
# ## EXPLATORY DATA ANALYSIS(EDA)

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
#plotting heat map for better understanding:
plt.figure(figsize=(9,5))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2, annot=True,fmt='f')
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# ### Describing the dataset:
#
#     The difference between :
#
#     1. Min and 25% for Happiness score is almost 1.69
#     2. 25% and 50% is 0.71
#     3. 50%-75% is alomst 1
#     4. 75% and max is 1.34
# - The mean > Median in Region column, which means data is right skewed.
# - Std deviation is high in Country, happiness rank and region. Which means data is highly spread.
# - High gap is present between 75% and max of Happiness rank,Country and considerable gap in region, std error,trust, generosity   and dystopia, which means outliers might be present.

# %% [markdown]
# ## Check Correlation of columns with the target:

# %%
df.corr() #correlation
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# Country                               0.083380        0.033879
# Region                               -0.176791       -0.022600
# Happiness Rank                       -0.992105        0.158516
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Country                                        0.037808  0.159416
# Region                                        -0.260139 -0.168533
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
#
#                                Health (Life Expectancy)   Freedom  \
# Country                                        0.037829  0.085684
# Region                                        -0.357508  0.092567
# Happiness Rank                                -0.735613 -0.556886
# Happiness Score                                0.724200  0.568211
# Standard Error                                -0.310287 -0.129773
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Country                                             0.088155    0.118085
# Region                                              0.165040    0.273557
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Country                                -0.019778
# Region                                 -0.057276
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(),cmap='Blues',annot=True,linewidth=0.5,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
#checking the columns which are positively and negatively corelated with the target column:

plt.figure(figsize=(12,7))
df.corr()["Happiness Score"].sort_values(ascending=False).drop(["Happiness Score"]).plot(kind='bar', color='b')
plt.xlabel('Variables',fontsize=14)
plt.ylabel("Happiness Score",fontsize=14)
plt.title("correlation",fontsize=15)
plt.show()

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# #### From the heat map it can be seen that the 'Happiness Score' is having maximum positive correlation with following factors:
# - Health (Life Expectancy)         0.724200 ==72%
# - Family                           0.740605 ==74%
# - Economy (GDP per Capita)         0.780966 ==78%
#
# And negative correlation with--
# - Happiness Rank                  -0.992105
# - Standard Error                  -0.177254
# - Region                          -0.176791

# %% [markdown]
# # Checking Outliers:

# %%
df.plot(kind='box',subplots=True,layout=(3,5),figsize=(10,10))
# Out:
# Country                             AxesSubplot(0.125,0.657941;0.133621x0.222059)
# Region                           AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# Happiness Rank                    AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# Happiness Score                  AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# Standard Error                   AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# Economy (GDP per Capita)            AxesSubplot(0.125,0.391471;0.133621x0.222059)
# Family                           AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# Health (Life Expectancy)          AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# Freedom                          AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# Trust (Government Corruption)    AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# Generosity                             AxesSubplot(0.125,0.125;0.133621x0.222059)
# Dystopia Residual                   AxesSubplot(0.285345,0.125;0.133621x0.222059)
# dtype: object

# %% [markdown]
# ##### Standard Error, Trust (Government Corruption), Dystopia Residual and Generosity shows some out of range data, which might be outliers.

# %% [markdown]
# ### REMOVING OUTLIERS

# %%
#use Zscore technique.
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 12)

# %%
#threshold for zscore values-----> above 3 are considered as outliers.

threshold=3
print(np.where(z>3))

#arrays are the index loc where outliers are present
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
z.iloc[27]  #At 27th index location outlier is present
# Out:
# Country                          0.800267
# Region                           0.375441
# Happiness Rank                   1.129016
# Happiness Score                  1.082256
# Standard Error                   0.859197
# Economy (GDP per Capita)         2.101026
# Family                           0.322476
# Health (Life Expectancy)         0.678336
# Freedom                          1.409878
# Trust (Government Corruption)    3.164619
# Generosity                       0.700286
# Dystopia Residual                0.982677
# Name: 27, dtype: float64

# %%
#Removing the outliers

df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 12 columns]

# %%
print('Old_DF:',df.shape)
print('New_DF:',df_new.shape)
print('total dropped rows:',df.shape[0]-df_new.shape[0])
# Out:
# Old_DF: (158, 12)
# New_DF: (149, 12)
# total dropped rows: 9

# %% [markdown]
# ### Percentage data loss
# Checking how many outliers are still there and if they help in the testing model or not.

# %%
loss_percent=(158-149)/158*100
print(loss_percent,'%')
# Out:
# 5.69620253164557 %

# %% [markdown]
# # Check Skewness

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#for checking all columns:

for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# Keeping +/- 0.5 as the threshold, Skewness is seen in
# - Standard Error
# - Family: Left skew
# - Health Life Expectancy- little left skewed
# - Trust (Government Corruption) - Shows right tail skew
# - Generosity

# %% [markdown]
# ## Removing the skewness
# #### transforming data to remove Skewness
# Seperating the coulumns in target and features

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
#removing the skewness from the clomns other than target column

from sklearn.preprocessing import power_transform
df2=power_transform(x,method='yeo-johnson')
df2
# Out:
# array([[ 1.17106926,  1.24453048, -2.06341393, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [-0.3443269 ,  1.24453048, -2.00849761, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [-0.84509236,  1.24453048, -1.95857395, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [ 1.18876946, -0.30300992,  1.52535242, ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [-1.28332767,  0.95510156,  1.54254416, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 1.27672507,  0.95510156,  1.55970548, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %%
#check if skewness is removed?
pd.DataFrame(df2).skew()
# Out:
# 0    -0.279791
# 1    -0.228041
# 2    -0.264365
# 3    -0.020092
# 4    -0.127233
# 5    -0.169651
# 6    -0.183181
# 7    -0.080728
# 8     0.185965
# 9     0.013320
# 10    0.022925
# dtype: float64

# %% [markdown]
# ## Scaling The Data using Min Max Scaler
# ### Since the data is continous we will use the linear regression model

# %%
from sklearn.preprocessing import MinMaxScaler #import Lin reg,r2score,TestTrainSplit,metrics
mms=MinMaxScaler()
lr=LinearRegression()
x=mms.fit_transform(x)
x
# Out:
# array([[0.85987261, 1.        , 0.        , ..., 0.76059502, 0.37289541,
#         0.66862987],
#        [0.36942675, 1.        , 0.00636943, ..., 0.25629179, 0.54819822,
#         0.72503024],
#        [0.23566879, 1.        , 0.01273885, ..., 0.87617546, 0.42894657,
#         0.66088906],
#        ...,
#        [0.86624204, 0.44444444, 0.98726115, ..., 0.34255585, 0.59279037,
#         0.        ],
#        [0.13375796, 0.88888889, 0.99363057, ..., 0.18231233, 0.247864  ,
#         0.45957306],
#        [0.89808917, 0.88888889, 1.        , ..., 0.19443388, 0.2095919 ,
#         0.37838928]])

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"At random state {i},the training accuracy is:",{r2_score(y_train,pred_train)})
    print(f"At random state {i} the testing accuracy is:",{r2_score(y_test,pred_test)})
    print("\n")
# Out:
# At random state 0,the training accuracy is: {0.9999999539093737}
# At random state 0 the testing accuracy is: {0.9999999124300164}
#
#
# At random state 1,the training accuracy is: {0.9999999469747698}
# At random state 1 the testing accuracy is: {0.9999999320614963}
#
#
# At random state 2,the training accuracy is: {0.9999999414364327}
# At random state 2 the testing accuracy is: {0.999999934389198}
#
#
# At random state 3,the training accuracy is: {0.9999999412735986}
# At random state 3 the testing accuracy is: {0.9999999382065095}
#
#
# At random state 4,the training accuracy is: {0.9999999359602336}
# At random state 4 the testing accuracy is: {0.9999999512240217}
#
#
# At random state 5,the training accuracy is: {0.999999947237999}
# At random state 5 the testing accuracy is: {0.9999999277574905}
#
#
# At random state 6,the training accuracy is: {0.9999999460667529}
# At random state 6 the testing accuracy is: {0.9999999341866798}
#
#
# At random state 7,the training accuracy is: {0.9999999488512962}
# At random state 7 the testing accuracy is: {0.9999999132816342}
#
#
# At random state 8,the training accuracy is: {0.9999999447291007}
# At random state 8 the testing accuracy is: {0.9999999372689758}
#
#
# At random state 9,the training accuracy is: {0.9999999456236456}
# At random state 9 the testing accuracy is: {0.9999999283323459}
#
#
# At random state 10,the training accuracy is: {0.9999999513923159}
# At random state 10 the testing accuracy is: {0.999999920473479}
#
#
# At random state 11,the training accuracy is: {0.9999999427119127}
# At random state 11 the testing accuracy is: {0.999999945708303}
#
#
# At random state 12,the training accuracy is: {0.9999999445721772}
# At random state 12 the testing accuracy is: {0.9999999337113714}
#
#
# At random state 13,the training accuracy is: {0.9999999481335484}
# At random state 13 the testing accuracy is: {0.9999999244887663}
#
#
# At random state 14,the training accuracy is: {0.9999999479663542}
# At random state 14 the testing accuracy is: {0.9999999304126842}
#
#
# At random state 15,the training accuracy is: {0.9999999433611949}
# At random state 15 the testing accuracy is: {0.999999935423561}
#
#
# At random state 16,the training accuracy is: {0.999999948726412}
# At random state 16 the testing accuracy is: {0.9999999284112177}
#
#
# At random state 17,the training accuracy is: {0.9999999480759936}
# At random state 17 the testing accuracy is: {0.9999999301427422}
#
#
# At random state 18,the training accuracy is: {0.9999999459707921}
# At random state 18 the testing accuracy is: {0.9999999373950331}
#
#
# At random state 19,the training accuracy is: {0.9999999454535596}
# At random state 19 the testing accuracy is: {0.9999999400571196}
#
#
# At random state 20,the training accuracy is: {0.9999999463115229}
# At random state 20 the testing accuracy is: {0.9999999310826666}
#
#
# At random state 21,the training accuracy is: {0.9999999522302003}
# At random state 21 the testing accuracy is: {0.9999999259346938}
#
#
# At random state 22,the training accuracy is: {0.9999999436272599}
# At random state 22 the testing accuracy is: {0.9999999410612191}
#
#
# At random state 23,the training accuracy is: {0.9999999518609273}
# At random state 23 the testing accuracy is: {0.9999999179350457}
#
#
# At random state 24,the training accuracy is: {0.9999999486567007}
# At random state 24 the testing accuracy is: {0.9999999268712969}
#
#
# At random state 25,the training accuracy is: {0.9999999510504334}
# At random state 25 the testing accuracy is: {0.9999999093108441}
#
#
# At random state 26,the training accuracy is: {0.9999999451835337}
# At random state 26 the testing accuracy is: {0.9999999344308702}
#
#
# At random state 27,the training accuracy is: {0.9999999536670644}
# At random state 27 the testing accuracy is: {0.9999999067135086}
#
#
# At random state 28,the training accuracy is: {0.9999999534948568}
# At random state 28 the testing accuracy is: {0.9999999106900472}
#
#
# At random state 29,the training accuracy is: {0.9999999512310891}
# At random state 29 the testing accuracy is: {0.9999999206352346}
#
#
# At random state 30,the training accuracy is: {0.9999999431476533}
# At random state 30 the testing accuracy is: {0.9999999367759724}
#
#
# At random state 31,the training accuracy is: {0.9999999482425542}
# At random state 31 the testing accuracy is: {0.9999999309320196}
#
#
# At random state 32,the training accuracy is: {0.9999999354493568}
# At random state 32 the testing accuracy is: {0.9999999536433629}
#
#
# At random state 33,the training accuracy is: {0.9999999325118547}
# At random state 33 the testing accuracy is: {0.9999999535628323}
#
#
# At random state 34,the training accuracy is: {0.9999999474763782}
# At random state 34 the testing accuracy is: {0.9999999222841056}
#
#
# At random state 35,the training accuracy is: {0.9999999539583785}
# At random state 35 the testing accuracy is: {0.9999999138891138}
#
#
# At random state 36,the training accuracy is: {0.999999939423027}
# At random state 36 the testing accuracy is: {0.9999999434303509}
#
#
# At random state 37,the training accuracy is: {0.9999999462338395}
# At random state 37 the testing accuracy is: {0.9999999362944277}
#
#
# At random state 38,the training accuracy is: {0.999999953614883}
# At random state 38 the testing accuracy is: {0.9999999044716545}
#
#
# At random state 39,the training accuracy is: {0.9999999447832227}
# At random state 39 the testing accuracy is: {0.9999999309879024}
#
#
# At random state 40,the training accuracy is: {0.9999999475129341}
# At random state 40 the testing accuracy is: {0.9999999332789455}
#
#
# At random state 41,the training accuracy is: {0.9999999459125343}
# At random state 41 the testing accuracy is: {0.9999999285485416}
#
#
# At random state 42,the training accuracy is: {0.9999999437535412}
# At random state 42 the testing accuracy is: {0.999999938156475}
#
#
# At random state 43,the training accuracy is: {0.9999999483317087}
# At random state 43 the testing accuracy is: {0.9999999310767823}
#
#
# At random state 44,the training accuracy is: {0.9999999495289168}
# At random state 44 the testing accuracy is: {0.9999999190552128}
#
#
# At random state 45,the training accuracy is: {0.9999999453594308}
# At random state 45 the testing accuracy is: {0.9999999377888897}
#
#
# At random state 46,the training accuracy is: {0.999999947437161}
# At random state 46 the testing accuracy is: {0.9999999250432815}
#
#
# At random state 47,the training accuracy is: {0.9999999494021546}
# At random state 47 the testing accuracy is: {0.9999999237312024}
#
#
# At random state 48,the training accuracy is: {0.999999948987409}
# At random state 48 the testing accuracy is: {0.9999999304624423}
#
#
# At random state 49,the training accuracy is: {0.9999999515869806}
# At random state 49 the testing accuracy is: {0.9999999129781593}
#
#
# At random state 50,the training accuracy is: {0.9999999404168146}
# At random state 50 the testing accuracy is: {0.9999999424220758}
#
#
# At random state 51,the training accuracy is: {0.9999999583427875}
# At random state 51 the testing accuracy is: {0.9999998936034353}
#
#
# At random state 52,the training accuracy is: {0.9999999489631044}
# At random state 52 the testing accuracy is: {0.9999999132730277}
#
#
# At random state 53,the training accuracy is: {0.9999999447262007}
# At random state 53 the testing accuracy is: {0.9999999333094862}
#
#
# At random state 54,the training accuracy is: {0.9999999356658871}
# At random state 54 the testing accuracy is: {0.9999999554279262}
#
#
# At random state 55,the training accuracy is: {0.9999999491665865}
# At random state 55 the testing accuracy is: {0.99999992395028}
#
#
# At random state 56,the training accuracy is: {0.9999999478083443}
# At random state 56 the testing accuracy is: {0.9999999276500083}
#
#
# At random state 57,the training accuracy is: {0.9999999460294352}
# At random state 57 the testing accuracy is: {0.9999999389301102}
#
#
# At random state 58,the training accuracy is: {0.999999954632451}
# At random state 58 the testing accuracy is: {0.9999998893340396}
#
#
# At random state 59,the training accuracy is: {0.9999999423507305}
# At random state 59 the testing accuracy is: {0.9999999262217961}
#
#
# At random state 60,the training accuracy is: {0.9999999428428644}
# At random state 60 the testing accuracy is: {0.9999999420459963}
#
#
# At random state 61,the training accuracy is: {0.9999999491769584}
# At random state 61 the testing accuracy is: {0.9999999276726883}
#
#
# At random state 62,the training accuracy is: {0.9999999555772063}
# At random state 62 the testing accuracy is: {0.999999911644279}
#
#
# At random state 63,the training accuracy is: {0.999999945127498}
# At random state 63 the testing accuracy is: {0.9999999381664729}
#
#
# At random state 64,the training accuracy is: {0.9999999430923703}
# At random state 64 the testing accuracy is: {0.9999999356484973}
#
#
# At random state 65,the training accuracy is: {0.9999999484569336}
# At random state 65 the testing accuracy is: {0.9999999313326885}
#
#
# At random state 66,the training accuracy is: {0.9999999468940518}
# At random state 66 the testing accuracy is: {0.9999999327883219}
#
#
# At random state 67,the training accuracy is: {0.9999999381804506}
# At random state 67 the testing accuracy is: {0.9999999534726044}
#
#
# At random state 68,the training accuracy is: {0.9999999486063494}
# At random state 68 the testing accuracy is: {0.9999999311959341}
#
#
# At random state 69,the training accuracy is: {0.9999999448404576}
# At random state 69 the testing accuracy is: {0.9999999393538974}
#
#
# At random state 70,the training accuracy is: {0.999999950350823}
# At random state 70 the testing accuracy is: {0.9999999285564966}
#
#
# At random state 71,the training accuracy is: {0.9999999437542413}
# At random state 71 the testing accuracy is: {0.9999999394178859}
#
#
# At random state 72,the training accuracy is: {0.9999999335527113}
# At random state 72 the testing accuracy is: {0.9999999371193105}
#
#
# At random state 73,the training accuracy is: {0.9999999475112664}
# At random state 73 the testing accuracy is: {0.9999999328918097}
#
#
# At random state 74,the training accuracy is: {0.9999999389326506}
# At random state 74 the testing accuracy is: {0.9999999507442678}
#
#
# At random state 75,the training accuracy is: {0.999999951482752}
# At random state 75 the testing accuracy is: {0.9999999166654432}
#
#
# At random state 76,the training accuracy is: {0.9999999571331594}
# At random state 76 the testing accuracy is: {0.9999998924180816}
#
#
# At random state 77,the training accuracy is: {0.9999999479206896}
# At random state 77 the testing accuracy is: {0.9999999309728627}
#
#
# At random state 78,the training accuracy is: {0.9999999482860384}
# At random state 78 the testing accuracy is: {0.9999999297656413}
#
#
# At random state 79,the training accuracy is: {0.9999999390657174}
# At random state 79 the testing accuracy is: {0.9999999498480695}
#
#
# At random state 80,the training accuracy is: {0.9999999489622617}
# At random state 80 the testing accuracy is: {0.9999999170965741}
#
#
# At random state 81,the training accuracy is: {0.9999999435634062}
# At random state 81 the testing accuracy is: {0.99999994207647}
#
#
# At random state 82,the training accuracy is: {0.9999999487681495}
# At random state 82 the testing accuracy is: {0.9999999274597152}
#
#
# At random state 83,the training accuracy is: {0.999999944969927}
# At random state 83 the testing accuracy is: {0.9999999322625549}
#
#
# At random state 84,the training accuracy is: {0.9999999366207205}
# At random state 84 the testing accuracy is: {0.9999999511879898}
#
#
# At random state 85,the training accuracy is: {0.9999999435692067}
# At random state 85 the testing accuracy is: {0.999999940574394}
#
#
# At random state 86,the training accuracy is: {0.9999999442563502}
# At random state 86 the testing accuracy is: {0.9999999395715387}
#
#
# At random state 87,the training accuracy is: {0.9999999415708158}
# At random state 87 the testing accuracy is: {0.999999946700345}
#
#
# At random state 88,the training accuracy is: {0.9999999476463203}
# At random state 88 the testing accuracy is: {0.9999999291620234}
#
#
# At random state 89,the training accuracy is: {0.9999999387561096}
# At random state 89 the testing accuracy is: {0.999999944047544}
#
#
# At random state 90,the training accuracy is: {0.9999999397317465}
# At random state 90 the testing accuracy is: {0.9999999413455506}
#
#
# At random state 91,the training accuracy is: {0.9999999489807881}
# At random state 91 the testing accuracy is: {0.999999923346158}
#
#
# At random state 92,the training accuracy is: {0.999999941288159}
# At random state 92 the testing accuracy is: {0.9999999422399184}
#
#
# At random state 93,the training accuracy is: {0.9999999513241955}
# At random state 93 the testing accuracy is: {0.9999999165295881}
#
#
# At random state 94,the training accuracy is: {0.9999999484350607}
# At random state 94 the testing accuracy is: {0.9999999230980889}
#
#
# At random state 95,the training accuracy is: {0.9999999493828059}
# At random state 95 the testing accuracy is: {0.9999999212490294}
#
#
# At random state 96,the training accuracy is: {0.9999999462533486}
# At random state 96 the testing accuracy is: {0.9999999378286905}
#
#
# At random state 97,the training accuracy is: {0.9999999481985032}
# At random state 97 the testing accuracy is: {0.9999999293778329}
#
#
# At random state 98,the training accuracy is: {0.9999999567646469}
# At random state 98 the testing accuracy is: {0.9999999029527429}
#
#
# At random state 99,the training accuracy is: {0.9999999510782646}
# At random state 99 the testing accuracy is: {0.9999999098567812}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=49)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9999999129781593

# %% [markdown]
# # Cross Validation Method

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for a in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=a)
    cv_mean=cv_score.mean()
    print(f"At cross fold {a}, the CV score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy score for testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2, the CV score is 0.9999997284501867 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 3, the CV score is 0.9999994758122854 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 4, the CV score is 0.9999988371717737 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 5, the CV score is 0.9999982417917263 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 6, the CV score is 0.9999971509064253 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 7, the CV score is 0.9999958018280702 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 8, the CV score is 0.9999955494387556 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593
#
#
# At cross fold 9, the CV score is 0.9999935863400461 and accuracy score for training is -0.9892095030847401 and accuracy score for testing is 0.9999999129781593

# %% [markdown]
# Since the folds arent having any impact on the accuracy score of training and testing, hence we can select cv=6.
# The Underfittinga nd Overfitting has been done in above steps using the R2 Score.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.scatter(x=y_test,y=pred_test,color='b')
plt.plot(y_test,y_test,color='r')
plt.xlabel("Actual values",fontsize=10)
plt.ylabel("Predicted values",fontsize=10)
plt.title("Linear regression")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### The best fit line is covering most of the point == model is trained and is a good fit.

# %% [markdown]
# ## Regularization techniques

# %%
from sklearn.linear_model import Lasso, Ridge

ls=Lasso(alpha=0.0001)
#ls=Lasso, alpha is set at 1.0 as default
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
predlasso=ls.predict(x_test)
print(mean_squared_error(y_test,predlasso))
print("Mean Squared error=",np.sqrt(mean_squared_error(y_test,predlasso)))
# Out:
# 0.9999856289618203
# 2.1561817201412624e-05
# Mean Squared error= 0.004643470383389198

# %%
#try to minimize the coeff variance

rd=Ridge(alpha=0.0001)
#rd=Ridge()
rd.fit(x_train,y_train)
print(rd.score(x_train,y_train))
predridge=rd.predict(x_test)
print(mean_squared_error(y_test,predridge))
print("Mean Squared error=",np.sqrt(mean_squared_error(y_test,predridge)))
# Out:
# 0.9999999397998468
# 1.4934962418180367e-07
# Mean Squared error= 0.0003864577909446304

# %%
#Elastic net is the combi of lasso and ridge
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
#enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))

print("Mean Squared error=",np.sqrt(mean_squared_error(y_test,predridge)))
# Out:
# 0.9999490926850246
# Mean Squared error= 0.0003864577909446304

# %% [markdown]
# ### From above, since the R2 Score in ridge regression is 0.9999, which is 99.99%, It can be said that the Ridge regression model works best!

# %% [markdown]
# ## Saving the model

# %%
import pickle
filename="World_happiness.pkl"
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# ## Conclusion:

# %%
loaded_model=pickle.load(open(filename,'rb'))

result =loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9999999129781593

# %%
Conc=pd.DataFrame([loaded_model.predict(x_test)[:],predridge[:]],index=['Predicted','Orginial'])
Conc
# Out:
#                  0         1         2         3         4         5   \
# Predicted  5.073290  4.076508  4.512213  5.101542  4.839078  5.548156
# Orginial   5.073321  4.076316  4.512024  5.101595  4.838957  5.548209
#
#                  6         7         8         9   ...        43        44  \
# Predicted  5.889097  3.955638  4.296497  6.797521  ...  5.193555  5.140544
# Orginial   5.889226  3.955592  4.296176  6.797439  ...  5.193608  5.140649
#
#                  45        46        47        48        49        50  \
# Predicted  7.284170  4.564505  3.780707  6.476978  4.517171  3.988773
# Orginial   7.284032  4.564346  3.780673  6.477055  4.517155  3.988659
#
#                  51        52
# Predicted  5.588617  6.328821
# Orginial   5.588584  6.328977
#
# [2 rows x 53 columns]

# %% [markdown]
# # END
